# %%
import os

os.getcwd()
# Out:
# 'c:\\Users\\Hp\\Desktop\\Projects\\10Academy\\fraud-detection\\notebooks'

# %%
os.listdir("..")
# Out:
# ['-p',
#  '.git',
#  '.github',
#  '.gitignore',
#  '.vscode',
#  'data',
#  'models',
#  'notebooks',
#  'requirements.txt',
#  'scripts',
#  'src',
#  'tests',
#  'venv']

# %%
import pandas as pd

fraud_df = pd.read_csv("../data/raw/Fraud_Data.csv")
fraud_df.head()
# Out:
#    user_id          signup_time        purchase_time  purchase_value  \
# 0    22058  2015-02-24 22:55:49  2015-04-18 02:47:11              34
# 1   333320  2015-06-07 20:39:50  2015-06-08 01:38:54              16
# 2     1359  2015-01-01 18:52:44  2015-01-01 18:52:45              15
# 3   150084  2015-04-28 21:13:25  2015-05-04 13:54:50              44
# 4   221365  2015-07-21 07:09:52  2015-09-09 18:40:53              39
#
#        device_id source browser sex  age    ip_address  class
# 0  QVPSPJUOCKZAR    SEO  Chrome   M   39  7.327584e+08      0
# 1  EOGFQPIZPYXFZ    Ads  Chrome   F   53  3.503114e+08      0
# 2  YSSKYOSJHPPLJ    SEO   Opera   M   53  2.621474e+09      1
# 3  ATGTXKYKUDUQN    SEO  Safari   M   41  3.840542e+09      0
# 4  NAUITBZFJKHWW    Ads  Safari   M   45  4.155831e+08      0

# %%
from xgboost import XGBClassifier

# %%
xgb_fraud = XGBClassifier(
    n_estimators=100,
    max_depth=4,
    learning_rate=0.1,
    random_state=42,
    eval_metric="logloss"
)

# %%
Xf = fraud_df.drop("class", axis=1)
yf = fraud_df["class"]

# %%
from sklearn.model_selection import train_test_split

Xf_train, Xf_test, yf_train, yf_test = train_test_split(
    Xf,
    yf,
    test_size=0.2,
    stratify=yf,
    random_state=42
)

# %%
Xf_train.shape
# Out:
# (120889, 10)

# %%
# keep only numerical columns for modeling

Xf_train = Xf_train.select_dtypes(include=["int64", "float64"])
Xf_test = Xf_test.select_dtypes(include=["int64", "float64"])

# %%
Xf_train.dtypes
# Out:
# user_id             int64
# purchase_value      int64
# age                 int64
# ip_address        float64
# dtype: object

# %%
from xgboost import XGBClassifier

xgb_fraud = XGBClassifier(
    n_estimators=100,
    max_depth=4,
    learning_rate=0.1,
    random_state=42,
    eval_metric="logloss"
)

# %%
xgb_fraud.fit(Xf_train, yf_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=4, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
import shap

explainer = shap.TreeExplainer(xgb_fraud)

shap_values = explainer.shap_values(Xf_test)

shap.summary_plot(
    shap_values,
    Xf_test
)

# %%
pred_xgb_fraud = xgb_fraud.predict(Xf_test)

# %%
pred_xgb_fraud[:5]
# Out:
# array([0, 0, 0, 0, 0])

# %%
import numpy as np

print("Actual fraud:", np.sum(yf_test == 1))
print("Predicted fraud:", np.sum(pred_xgb_fraud == 1))

print("TP count:", np.sum((yf_test == 1) & (pred_xgb_fraud == 1)))
print("FP count:", np.sum((yf_test == 0) & (pred_xgb_fraud == 1)))
print("FN count:", np.sum((yf_test == 1) & (pred_xgb_fraud == 0)))
# Out:
# Actual fraud: 2830
# Predicted fraud: 0
# TP count: 0
# FP count: 0
# FN count: 2830

# %%
yf_train.value_counts()
# Out:
# class
# 0    109568
# 1     11321
# Name: count, dtype: int64

# %%
scale = yf_train.value_counts()[0] / yf_train.value_counts()[1]

scale
# Out:
# np.float64(9.678296970232312)

# %%
from xgboost import XGBClassifier

xgb_fraud = XGBClassifier(
    n_estimators=200,
    max_depth=4,
    learning_rate=0.1,
    scale_pos_weight=scale,
    random_state=42,
    eval_metric="logloss"
)

# %%
xgb_fraud.fit(Xf_train, yf_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=4, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
pred_xgb_fraud = xgb_fraud.predict(Xf_test)

# %%
print("Predicted fraud:", np.sum(pred_xgb_fraud == 1))
# Out:
# Predicted fraud: 11883

# %%
import numpy as np

tp_idx = np.where(
    (yf_test == 1) & (pred_xgb_fraud == 1)
)[0][0]

fp_idx = np.where(
    (yf_test == 0) & (pred_xgb_fraud == 1)
)[0][0]

fn_idx = np.where(
    (yf_test == 1) & (pred_xgb_fraud == 0)
)[0][0]

print("TP:", tp_idx)
print("FP:", fp_idx)
print("FN:", fn_idx)
# Out:
# TP: 2
# FP: 1
# FN: 17

# %%
shap.force_plot(
    explainer.expected_value,
    shap_values[tp_idx],
    Xf_test.iloc[tp_idx],
    matplotlib=True
)

# %%
explainer = shap.TreeExplainer(xgb_fraud)

shap_values = explainer.shap_values(Xf_test)
